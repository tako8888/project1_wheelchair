# %%
import pandas as pd  # 文字数を節約
# %matplotlib inline

# %%
# !ls
# Out:
# MTA_NYCT_Subway_Elevator_and_Escalator_Availability__Beginning_2015_20240627.csv
# Untitled.ipynb

# %%
df = pd.read_csv("MTA_NYCT_Subway_Elevator_and_Escalator_Availability__Beginning_2015_20240627.csv", # csvファイルのパス
                 #sep="\t", # tabをseparator
                 #encoding="iso8859-1", # encode
                #na_values=[0],
                parse_dates=['Month']
                ) # None 

# 全部表示させる
pd.options.display.max_colwidth = None
pd.set_option('display.max_columns', None)
                
df.head()
# Out:
#        Month    Borough Equipment Type Equipment Code  Total Outages  \
# 0 2015-01-01     Queens       Elevator          EL426              2
# 1 2015-01-01     Queens       Elevator          EL411              6
# 2 2015-01-01   Brooklyn      Escalator          ES332             16
# 3 2015-01-01     Queens       Elevator         EL449X              0
# 4 2015-01-01  Manhattan      Escalator          ES239              7
#
#    Scheduled Outages  Unscheduled Outages  Entrapments  \
# 0                  2                    0            0
# 1                  5                    1            0
# 2                  3                   13            0
# 3                  0                    0            0
# 4                  3                    4            0
#
#    Time Since Major Improvement  AM Peak Availability  \
# 0                          95.0              1.000000
# 1                         313.0              0.984677
# 2                         143.0              0.958199
# 3                           NaN              1.000000
# 4                         189.0              0.978898
#
#    AM Peak Hours Available  AM Peak Total Hours  PM Peak Availability  \
# 0               124.000000                124.0              1.000000
# 1               122.100000                124.0              0.981586
# 2               118.816667                124.0              0.903360
# 3               124.000000                124.0              1.000000
# 4               121.383333                124.0              0.973790
#
#    PM Peak Hours Available  PM Peak Total Hours  24-Hour Availability  \
# 0               124.000000                124.0              0.986022
# 1               121.716667                124.0              0.962522
# 2               112.016667                124.0              0.932684
# 3               124.000000                124.0              1.000000
# 4               120.750000                124.0              0.964315
#
#    24-Hour Hours Available  24-Hour Total Hours  \
# 0               733.600000                744.0
# 1               716.116667                744.0
# 2               693.916667                744.0
# 3               744.000000                744.0
# 4               717.450000                744.0
#
#                                 Station Name  Station MRN  \
# 0                         JUNCTIONBLVD-FLS-7          451
# 1  SUTPHINBLVD-ARCHERAV-JFKAIRPORT-QBL-E/J/Z          279
# 2                    MYRTLE-WYCKOFFAVS-MYT-M          112
# 3  SUTPHINBLVD-ARCHERAV-JFKAIRPORT-QBL-E/J/Z          279
# 4                           5AV/53ST-QBL-E/M          276
#
#                            Station Complex Name  Station Complex MRN
# 0                       Junction Blvd - Station                  451
# 1  Sutphin Blvd-Archer Av-JFK Airport - Station                  279
# 2                      Myrtle-Wyckoff Avs (L,M)                  630
# 3  Sutphin Blvd-Archer Av-JFK Airport - Station                  279
# 4                          5 Av/53 St - Station                  276

# %%
print(df.nunique(dropna=False))# これが初期の呪文としてよろしいかと

df.info()
# Out:
# Month                             113
# Borough                             4
# Equipment Type                      2
# Equipment Code                    652
# Total Outages                      69
# Scheduled Outages                  36
# Unscheduled Outages                61
# Entrapments                        10
# Time Since Major Improvement      723
# AM Peak Availability             6178
# AM Peak Hours Available          4778
# AM Peak Total Hours               442
# PM Peak Availability             6463
# PM Peak Hours Available          5039
# PM Peak Total Hours               390
# 24-Hour Availability            18165
# 24-Hour Hours Available         12064
# 24-Hour Total Hours              1586
# Station Name                      166
# Station MRN                       166
# Station Complex Name              125
# Station Complex MRN               136
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64880 entries, 0 to 64879
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         64880 non-null  datetime64[ns]
#  1   Borough                       64880 non-null  object
#  2   Equipment Type                64880 non-null  object
#  3   Equipment Code                64880 non-null  object
#  4   Total Outages                 64880 non-null  int64
#  5   Scheduled Outages             64880 non-null  int64
#  6   Unscheduled Outages           64880 non-null  int64
#  7   Entrapments                   64880 non-null  int64
#  8   Time Since Major Improvement  54845 non-null  float64
#  9   AM Peak Availability          63417 non-null  float64
#  10  AM Peak Hours Available       64880 non-null  float64
#  11  AM Peak Total Hours           64880 non-null  float64
#  12  PM Peak Availability          63429 non-null  float64
#  13  PM Peak Hours Available       64880 non-null  float64
#  14  PM Peak Total Hours           64880 non-null  float64
#  15  24-Hour Availability          63438 non-null  float64
#  16  24-Hour Hours Available       64880 non-null  float64
#  17  24-Hour Total Hours           64880 non-null  float64
#  18  Station Name                  64880 non-null  object
#  19  Station MRN                   64880 non-null  int64
#  20  Station Complex Name          64880 non-null  object
#  21  Station Complex MRN           64880 non-null  int64
# dtypes: datetime64[ns](1), float64(10), int64(6), object(5)
# memory usage: 10.9+ MB

# %%
df.groupby('Month')['24-Hour Availability'].sum().plot()
# availability elevators and escalators
# Out:
# <Axes: xlabel='Month'>

# %%
df[df['Equipment Type'] == "Elevator"].groupby('Month')['24-Hour Hours Available'].sum().plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df[df['Equipment Type'] == "Elevator"].value_counts('Equipment Code')
# Out:
# Equipment Code
# EL103    113
# EL343    113
# EL372    113
# EL371    113
# EL370    113
#         ...
# EL780      2
# EL781      2
# EL778      2
# EL776      2
# EL777      2
# Name: count, Length: 370, dtype: int64

# %%
df[df['Equipment Type'] == "Elevator"].value_counts('Month').plot()
# Out:
# <Axes: xlabel='Month'>

# %%
elevator_df = df[df['Equipment Type'] == "Elevator"]

# %%
# Step 2: Group by 'Borough' and 'Month', then count the occurrences
grouped_data = elevator_df.groupby(['Borough', 'Month']).size().unstack('Borough')
grouped_data
# Out:
# Borough     Bronx  Brooklyn  Manhattan  Queens
# Month
# 2015-01-01     32        55        130      43
# 2015-02-01     32        55        130      43
# 2015-03-01     32        55        130      43
# 2015-04-01     32        55        130      43
# 2015-05-01     32        55        130      43
# ...           ...       ...        ...     ...
# 2024-01-01     42        84        181      54
# 2024-02-01     45        84        181      54
# 2024-03-01     45        84        181      54
# 2024-04-01     45        90        181      54
# 2024-05-01     45        90        181      54
#
# [113 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

grouped_data.plot(kind='line')
plt.xlabel('Month')
plt.ylabel('Number of Elevators')
plt.title('Number of Elevator Installations Over Time by Borough')
plt.legend(title='Borough')
plt.show()

# %%
# Step 2: Group by 'Borough' and 'Month', then count the occurrences
groupeddata2 = (elevator_df
                .groupby(['Borough', 'Month'])
                ['24-Hour Availability']
                .sum().reset_index()
)

# %%
# ピボットテーブルを作成
pivot_data = groupeddata2.pivot_table(index='Month', columns='Borough', values='24-Hour Availability', aggfunc='sum')

# プロット
pivot_data.plot(kind='line', figsize=(10, 6))
plt.xlabel('Month')
plt.ylabel('Total 24-Hour Availability')
plt.title('Total 24-Hour Availability of Elevators by Borough Over Time')
plt.legend(title='Borough')
plt.show()

# %% [markdown]
# # たぶん、Boroughごとのエレベーター準備率が出せるな。稼働分数/全ての駅の数*24みたいな感じで。
